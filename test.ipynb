# %%
from pathlib import Path
from hotel_id_nns.nn.datasets.h5_hotel_dataset import H5HotelDataset

ds = H5HotelDataset(Path("/home/claudiusk/_Studium/hotel-id-nns/data/dataset/hotel_test_chain.h5"), config={"remove_unkown_chain_id_samples": False})
# Out:
# loading dataset from path /home/claudiusk/_Studium/hotel-id-nns/data/dataset/hotel_test_chain.h5

# %%
import pandas as pd
import torch
from matplotlib import pyplot as plt

df = pd.DataFrame(ds.hotel_ids)
indices = (ds.hotel_ids == 415).nonzero()
f, axes = plt.subplots(4,4)
for ax, index in zip(axes.flat, indices):
    img = torch.as_tensor(ds.imgs[index])
    plt.figure()
    ax.imshow(img.transpose(0,2).transpose(0,1))
    ax.axis("off")

# %%
    img.transpose()
